# %% [markdown]
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://githubtocolab.com/giswqs/geemap/blob/master/examples/notebooks/103_split_control.ipynb)
# [![image](https://mybinder.org/badge_logo.svg)](https://gishub.org/geemap-binder)
#
# **Creating a split-panel map**
#
# This notebook demonstrates how to add a split-panel map with geemap and folium. It also supports streamlit. Note that the ipyleaflet SplitControl does not support streamlit.
#
# Uncomment the following line to install [geemap](https://geemap.org) if needed.

# %%
pip install geemap
# Out:
# Requirement already satisfied: geemap in /home/joy/.local/lib/python3.8/site-packages (0.16.2)
# Requirement already satisfied: pyshp>=2.1.3 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (2.3.1)
# Requirement already satisfied: sankee>=0.1.0 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: ipytree in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.2.1)
# Requirement already satisfied: geocoder in /home/joy/.local/lib/python3.8/site-packages (from geemap) (1.38.1)
# Requirement already satisfied: colour in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.1.5)
# Requirement already satisfied: python-box in /home/joy/.local/lib/python3.8/site-packages (from geemap) (6.0.2)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.17.0)
# Requirement already satisfied: pillow in /home/joy/.local/lib/python3.8/site-packages (from geemap) (9.1.1)
# Requirement already satisfied: numpy in /home/joy/.local/lib/python3.8/site-packages (from geemap) (1.23.1)
# Requirement already satisfied: xyzservices in /home/joy/.local/lib/python3.8/site-packages (from geemap) (2022.6.0)
# Requirement already satisfied: scooby in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: gdown in /home/joy/.local/lib/python3.8/site-packages (from geemap) (4.5.1)
# Requirement already satisfied: ipyevents in /home/joy/.local/lib/python3.8/site-packages (from geemap) (2.0.1)
# Requirement already satisfied: whiteboxgui>=0.6.0 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.7.0)
# Requirement already satisfied: bqplot in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.12.33)
# Requirement already satisfied: geeadd>=0.5.1 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.5.5)
# Requirement already satisfied: geojson in /home/joy/.local/lib/python3.8/site-packages (from geemap) (2.5.0)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.6.0)
# Requirement already satisfied: matplotlib in /home/joy/.local/lib/python3.8/site-packages (from geemap) (3.5.2)
# Requirement already satisfied: pandas in /home/joy/.local/lib/python3.8/site-packages (from geemap) (1.4.3)
# Requirement already satisfied: ee-extra>=0.0.10 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.0.14)
# Requirement already satisfied: ffmpeg-python in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.2.0)
# Requirement already satisfied: folium>=0.11.0 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.12.1.post1)
# Requirement already satisfied: pycrs in /home/joy/.local/lib/python3.8/site-packages (from geemap) (1.0.2)
# Requirement already satisfied: earthengine-api>=0.1.304 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (0.1.318)
# Requirement already satisfied: jupyterlab>=3 in /home/joy/.local/lib/python3.8/site-packages (from geemap) (3.4.4)
# Requirement already satisfied: plotly>=5.2.2 in /home/joy/.local/lib/python3.8/site-packages (from sankee>=0.1.0->geemap) (5.9.0)
# Requirement already satisfied: ipywidgets in /home/joy/.local/lib/python3.8/site-packages (from sankee>=0.1.0->geemap) (7.7.1)
# Requirement already satisfied: ratelim in /home/joy/.local/lib/python3.8/site-packages (from geocoder->geemap) (0.1.6)
# Requirement already satisfied: future in /usr/lib/python3/dist-packages (from geocoder->geemap) (0.18.2)
# Requirement already satisfied: requests in /home/joy/.local/lib/python3.8/site-packages (from geocoder->geemap) (2.28.0)
# Requirement already satisfied: six in /home/joy/.local/lib/python3.8/site-packages (from geocoder->geemap) (1.16.0)
# Requirement already satisfied: click in /home/joy/.local/lib/python3.8/site-packages (from geocoder->geemap) (8.0.3)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/joy/.local/lib/python3.8/site-packages (from ipyleaflet>=0.17.0->geemap) (0.2.1)
# Requirement already satisfied: beautifulsoup4 in /home/joy/.local/lib/python3.8/site-packages (from gdown->geemap) (4.11.1)
# Requirement already satisfied: tqdm in /home/joy/.local/lib/python3.8/site-packages (from gdown->geemap) (4.64.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from gdown->geemap) (3.0.12)
# Requirement already satisfied: whitebox in /home/joy/.local/lib/python3.8/site-packages (from whiteboxgui>=0.6.0->geemap) (2.1.4)
# Requirement already satisfied: traitlets>=4.3.0 in /home/joy/.local/lib/python3.8/site-packages (from bqplot->geemap) (5.3.0)
# Requirement already satisfied: logzero>=1.5.0 in /home/joy/.local/lib/python3.8/site-packages (from geeadd>=0.5.1->geemap) (1.7.0)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3/dist-packages (from matplotlib->geemap) (20.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->geemap) (2.4.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->geemap) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->geemap) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->geemap) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->geemap) (4.34.4)
# Requirement already satisfied: pytz>=2020.1 in /home/joy/.local/lib/python3.8/site-packages (from pandas->geemap) (2021.3)
# Requirement already satisfied: branca>=0.3.0 in /home/joy/.local/lib/python3.8/site-packages (from folium>=0.11.0->geemap) (0.5.0)
# Requirement already satisfied: jinja2>=2.9 in /home/joy/.local/lib/python3.8/site-packages (from folium>=0.11.0->geemap) (3.0.2)
# Requirement already satisfied: google-cloud-storage in /home/joy/.local/lib/python3.8/site-packages (from earthengine-api>=0.1.304->geemap) (2.5.0)
# Requirement already satisfied: httplib2<1dev,>=0.9.2 in /usr/lib/python3/dist-packages (from earthengine-api>=0.1.304->geemap) (0.14.0)
# Requirement already satisfied: httplib2shim in /home/joy/.local/lib/python3.8/site-packages (from earthengine-api>=0.1.304->geemap) (0.0.3)
# Requirement already satisfied: google-auth>=1.4.1 in /home/joy/.local/lib/python3.8/site-packages (from earthengine-api>=0.1.304->geemap) (2.9.1)
# Requirement already satisfied: google-auth-httplib2>=0.0.3 in /home/joy/.local/lib/python3.8/site-packages (from earthengine-api>=0.1.304->geemap) (0.1.0)
# Requirement already satisfied: google-api-python-client<2,>=1.12.1 in /home/joy/.local/lib/python3.8/site-packages (from earthengine-api>=0.1.304->geemap) (1.12.11)
# Requirement already satisfied: notebook<7 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (6.4.12)
# Requirement already satisfied: tornado>=6.1.0 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (6.2)
# Requirement already satisfied: ipython in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (8.4.0)
# Requirement already satisfied: nbclassic in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (0.4.3)
# Requirement already satisfied: jupyterlab-server~=2.10 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (2.15.0)
# Requirement already satisfied: jupyter-core in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (4.11.1)
# Requirement already satisfied: jupyter-server~=1.16 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3->geemap) (1.18.1)
# Requirement already satisfied: tenacity>=6.2.0 in /home/joy/.local/lib/python3.8/site-packages (from plotly>=5.2.2->sankee>=0.1.0->geemap) (8.0.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets->sankee>=0.1.0->geemap) (1.1.1)
# Requirement already satisfied: ipykernel>=4.5.1 in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets->sankee>=0.1.0->geemap) (6.15.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets->sankee>=0.1.0->geemap) (3.6.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets->sankee>=0.1.0->geemap) (0.2.0)
# Requirement already satisfied: decorator in /home/joy/.local/lib/python3.8/site-packages (from ratelim->geocoder->geemap) (5.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/joy/.local/lib/python3.8/site-packages (from requests->geocoder->geemap) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/joy/.local/lib/python3.8/site-packages (from requests->geocoder->geemap) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/joy/.local/lib/python3.8/site-packages (from requests->geocoder->geemap) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/joy/.local/lib/python3.8/site-packages (from requests->geocoder->geemap) (2.0.12)
# Requirement already satisfied: soupsieve>1.2 in /home/joy/.local/lib/python3.8/site-packages (from beautifulsoup4->gdown->geemap) (2.3.2.post1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/joy/.local/lib/python3.8/site-packages (from jinja2>=2.9->folium>=0.11.0->geemap) (2.1.1)
# Requirement already satisfied: google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5 in /home/joy/.local/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.8.2)
# Requirement already satisfied: google-cloud-core<3.0dev,>=2.3.0 in /home/joy/.local/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.2)
# Requirement already satisfied: google-resumable-media>=2.3.2 in /home/joy/.local/lib/python3.8/site-packages (from google-cloud-storage->earthengine-api>=0.1.304->geemap) (2.3.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/joy/.local/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/joy/.local/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /home/joy/.local/lib/python3.8/site-packages (from google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (4.9)
# Requirement already satisfied: uritemplate<4dev,>=3.0.0 in /home/joy/.local/lib/python3.8/site-packages (from google-api-python-client<2,>=1.12.1->earthengine-api>=0.1.304->geemap) (3.0.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (1.8.0)
# Requirement already satisfied: pyzmq>=17 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (23.2.0)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (7.3.4)
# Requirement already satisfied: argon2-cffi in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (21.3.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (0.15.0)
# Requirement already satisfied: prometheus-client in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (6.5.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (1.5.5)
# Requirement already satisfied: nbformat in /home/joy/.local/lib/python3.8/site-packages (from notebook<7->jupyterlab>=3->geemap) (5.4.0)
# Requirement already satisfied: matplotlib-inline in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (0.1.3)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython->jupyterlab>=3->geemap) (4.6.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (2.12.0)
# Requirement already satisfied: stack-data in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (0.3.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (3.0.30)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->jupyterlab>=3->geemap) (45.2.0)
# Requirement already satisfied: backcall in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: pickleshare in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3->geemap) (0.7.5)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3->geemap) (0.1.0)
# Requirement already satisfied: jsonschema>=3.0.1 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.5.1)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (4.11.3)
# Requirement already satisfied: babel in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (2.10.3)
# Requirement already satisfied: json5 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.9.9)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/joy/.local/lib/python3.8/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (3.6.1)
# Requirement already satisfied: websocket-client in /home/joy/.local/lib/python3.8/site-packages (from jupyter-server~=1.16->jupyterlab>=3->geemap) (1.3.3)
# Requirement already satisfied: debugpy>=1.0 in /home/joy/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets->sankee>=0.1.0->geemap) (1.6.2)
# Requirement already satisfied: psutil in /home/joy/.local/lib/python3.8/site-packages (from ipykernel>=4.5.1->ipywidgets->sankee>=0.1.0->geemap) (5.9.1)
# Requirement already satisfied: protobuf<5.0.0dev,>=3.15.0 in /home/joy/.local/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->earthengine-api>=0.1.304->geemap) (4.21.4)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/joy/.local/lib/python3.8/site-packages (from google-api-core!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.0,<3.0.0dev,>=1.31.5->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.56.4)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/joy/.local/lib/python3.8/site-packages (from google-resumable-media>=2.3.2->google-cloud-storage->earthengine-api>=0.1.304->geemap) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/joy/.local/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.4.1->earthengine-api>=0.1.304->geemap) (0.4.8)
# Requirement already satisfied: entrypoints in /usr/lib/python3/dist-packages (from jupyter-client>=5.3.4->notebook<7->jupyterlab>=3->geemap) (0.3)
# Requirement already satisfied: argon2-cffi-bindings in /home/joy/.local/lib/python3.8/site-packages (from argon2-cffi->notebook<7->jupyterlab>=3->geemap) (21.2.0)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/joy/.local/lib/python3.8/site-packages (from terminado>=0.8.3->notebook<7->jupyterlab>=3->geemap) (0.7.0)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (0.8.4)
# Requirement already satisfied: defusedxml in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: nbclient>=0.5.0 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (0.6.6)
# Requirement already satisfied: tinycss2 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (1.1.1)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (1.5.0)
# Requirement already satisfied: bleach in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (5.0.1)
# Requirement already satisfied: fastjsonschema in /home/joy/.local/lib/python3.8/site-packages (from nbformat->notebook<7->jupyterlab>=3->geemap) (2.16.1)
# Requirement already satisfied: asttokens in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (2.0.5)
# Requirement already satisfied: executing in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (0.9.1)
# Requirement already satisfied: pure-eval in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3->geemap) (0.2.2)
# Requirement already satisfied: wcwidth in /home/joy/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3->geemap) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/joy/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyterlab>=3->geemap) (0.8.3)
# Requirement already satisfied: attrs>=17.4.0 in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (5.7.1)
# Requirement already satisfied: zipp>=0.5 in /home/joy/.local/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->jupyterlab-server~=2.10->jupyterlab>=3->geemap) (3.8.0)
# Requirement already satisfied: sniffio>=1.1 in /home/joy/.local/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3->geemap) (1.2.0)
# Requirement already satisfied: cffi>=1.0.1 in /home/joy/.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook<7->jupyterlab>=3->geemap) (1.14.0)
# Requirement already satisfied: webencodings>=0.4 in /home/joy/.local/lib/python3.8/site-packages (from tinycss2->nbconvert>=5->notebook<7->jupyterlab>=3->geemap) (0.5.1)
# Requirement already satisfied: pycparser in /home/joy/.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook<7->jupyterlab>=3->geemap) (2.19)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install leafmap
# Out:
# Collecting leafmap
#   Downloading leafmap-0.10.3-py2.py3-none-any.whl (161 kB)
#      |████████████████████████████████| 161 kB 613 kB/s eta 0:00:01
# Requirement already satisfied: jupyterlab>=3.0.0 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (3.4.4)
# Requirement already satisfied: ipyleaflet>=0.17.0 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.17.0)
# Requirement already satisfied: pyshp>=2.1.3 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (2.3.1)
# Requirement already satisfied: bqplot in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.12.33)
# Requirement already satisfied: ipyfilechooser>=0.6.0 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: pycrs in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (1.0.2)
# Requirement already satisfied: python-box in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (6.0.2)
# Collecting ipysheet
#   Downloading ipysheet-0.5.0-py2.py3-none-any.whl (3.8 MB)
#      |████████████████████████████████| 3.8 MB 404 kB/s eta 0:00:01
# Requirement already satisfied: geojson in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (2.5.0)
# Requirement already satisfied: folium>=0.11.0 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.12.1.post1)
# Requirement already satisfied: ipyevents in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (2.0.1)
# Requirement already satisfied: scooby in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.6.0)
# Requirement already satisfied: xyzservices in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (2022.6.0)
# Requirement already satisfied: pandas in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (1.4.3)
# Requirement already satisfied: gdown in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (4.5.1)
# Requirement already satisfied: matplotlib in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (3.5.2)
# Requirement already satisfied: colour in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.1.5)
# Requirement already satisfied: numpy in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (1.23.1)
# Collecting pystac-client
#   Downloading pystac_client-0.4.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: whiteboxgui>=0.6.0 in /home/joy/.local/lib/python3.8/site-packages (from leafmap) (0.7.0)
# Requirement already satisfied: nbclassic in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (0.4.3)
# Requirement already satisfied: ipython in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (8.4.0)
# Requirement already satisfied: jinja2>=2.1 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (3.0.2)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from jupyterlab>=3.0.0->leafmap) (20.3)
# Requirement already satisfied: jupyterlab-server~=2.10 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (2.15.0)
# Requirement already satisfied: jupyter-server~=1.16 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (1.18.1)
# Requirement already satisfied: notebook<7 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (6.4.12)
# Requirement already satisfied: jupyter-core in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (4.11.1)
# Requirement already satisfied: tornado>=6.1.0 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab>=3.0.0->leafmap) (6.2)
# Requirement already satisfied: traittypes<3,>=0.2.1 in /home/joy/.local/lib/python3.8/site-packages (from ipyleaflet>=0.17.0->leafmap) (0.2.1)
# Requirement already satisfied: ipywidgets<8,>=7.6.0 in /home/joy/.local/lib/python3.8/site-packages (from ipyleaflet>=0.17.0->leafmap) (7.7.1)
# Requirement already satisfied: traitlets>=4.3.0 in /home/joy/.local/lib/python3.8/site-packages (from bqplot->leafmap) (5.3.0)
# Requirement already satisfied: branca>=0.3.0 in /home/joy/.local/lib/python3.8/site-packages (from folium>=0.11.0->leafmap) (0.5.0)
# Requirement already satisfied: requests in /home/joy/.local/lib/python3.8/site-packages (from folium>=0.11.0->leafmap) (2.28.0)
# Requirement already satisfied: pytz>=2020.1 in /home/joy/.local/lib/python3.8/site-packages (from pandas->leafmap) (2021.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/joy/.local/lib/python3.8/site-packages (from pandas->leafmap) (2.8.2)
# Requirement already satisfied: beautifulsoup4 in /home/joy/.local/lib/python3.8/site-packages (from gdown->leafmap) (4.11.1)
# Requirement already satisfied: tqdm in /home/joy/.local/lib/python3.8/site-packages (from gdown->leafmap) (4.64.0)
# Requirement already satisfied: six in /home/joy/.local/lib/python3.8/site-packages (from gdown->leafmap) (1.16.0)
# Requirement already satisfied: filelock in /usr/lib/python3/dist-packages (from gdown->leafmap) (3.0.12)
# Requirement already satisfied: fonttools>=4.22.0 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->leafmap) (4.34.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3/dist-packages (from matplotlib->leafmap) (2.4.6)
# Requirement already satisfied: cycler>=0.10 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->leafmap) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->leafmap) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/joy/.local/lib/python3.8/site-packages (from matplotlib->leafmap) (9.1.1)
# Collecting pystac>=1.4.0
#   Downloading pystac-1.6.1-py3-none-any.whl (146 kB)
#      |████████████████████████████████| 146 kB 1.7 MB/s eta 0:00:01
# Requirement already satisfied: ipytree in /home/joy/.local/lib/python3.8/site-packages (from whiteboxgui>=0.6.0->leafmap) (0.2.1)
# Requirement already satisfied: whitebox in /home/joy/.local/lib/python3.8/site-packages (from whiteboxgui>=0.6.0->leafmap) (2.1.4)
# Requirement already satisfied: ipython-genutils in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (0.2.0)
# Requirement already satisfied: prometheus-client in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (0.14.1)
# Requirement already satisfied: nbconvert>=5 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (6.5.0)
# Requirement already satisfied: ipykernel in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (6.15.1)
# Requirement already satisfied: jupyter-client>=6.1.1 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (7.3.4)
# Requirement already satisfied: nbformat in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (5.4.0)
# Requirement already satisfied: terminado>=0.8.3 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (0.15.0)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (1.5.5)
# Requirement already satisfied: argon2-cffi in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (21.3.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (1.8.0)
# Requirement already satisfied: notebook-shim>=0.1.0 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (0.1.0)
# Requirement already satisfied: pyzmq>=17 in /home/joy/.local/lib/python3.8/site-packages (from nbclassic->jupyterlab>=3.0.0->leafmap) (23.2.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/lib/python3/dist-packages (from ipython->jupyterlab>=3.0.0->leafmap) (45.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (3.0.30)
# Requirement already satisfied: pickleshare in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.7.5)
# Requirement already satisfied: stack-data in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.3.0)
# Requirement already satisfied: jedi>=0.16 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.1.3)
# Requirement already satisfied: pygments>=2.4.0 in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (2.12.0)
# Requirement already satisfied: pexpect>4.3; sys_platform != "win32" in /usr/lib/python3/dist-packages (from ipython->jupyterlab>=3.0.0->leafmap) (4.6.0)
# Requirement already satisfied: backcall in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (0.2.0)
# Requirement already satisfied: decorator in /home/joy/.local/lib/python3.8/site-packages (from ipython->jupyterlab>=3.0.0->leafmap) (5.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/joy/.local/lib/python3.8/site-packages (from jinja2>=2.1->jupyterlab>=3.0.0->leafmap) (2.1.1)
# Requirement already satisfied: jsonschema>=3.0.1 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (4.5.1)
# Requirement already satisfied: json5 in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (0.9.9)
# Requirement already satisfied: babel in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (2.10.3)
# Requirement already satisfied: importlib-metadata>=3.6; python_version < "3.10" in /home/joy/.local/lib/python3.8/site-packages (from jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (4.11.3)
# Requirement already satisfied: anyio<4,>=3.1.0 in /home/joy/.local/lib/python3.8/site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (3.6.1)
# Requirement already satisfied: websocket-client in /home/joy/.local/lib/python3.8/site-packages (from jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.3.3)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0; python_version >= "3.6" in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.17.0->leafmap) (1.1.1)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /home/joy/.local/lib/python3.8/site-packages (from ipywidgets<8,>=7.6.0->ipyleaflet>=0.17.0->leafmap) (3.6.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/joy/.local/lib/python3.8/site-packages (from requests->folium>=0.11.0->leafmap) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/joy/.local/lib/python3.8/site-packages (from requests->folium>=0.11.0->leafmap) (2022.6.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/joy/.local/lib/python3.8/site-packages (from requests->folium>=0.11.0->leafmap) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/joy/.local/lib/python3.8/site-packages (from requests->folium>=0.11.0->leafmap) (1.26.9)
# Requirement already satisfied: soupsieve>1.2 in /home/joy/.local/lib/python3.8/site-packages (from beautifulsoup4->gdown->leafmap) (2.3.2.post1)
# Requirement already satisfied: Click>=6.0 in /home/joy/.local/lib/python3.8/site-packages (from whitebox->whiteboxgui>=0.6.0->leafmap) (8.0.3)
# Requirement already satisfied: defusedxml in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.7.1)
# Requirement already satisfied: bleach in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (5.0.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.6.6)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (1.5.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/lib/python3/dist-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.3)
# Requirement already satisfied: jupyterlab-pygments in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.2.2)
# Requirement already satisfied: tinycss2 in /home/joy/.local/lib/python3.8/site-packages (from nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (1.1.1)
# Requirement already satisfied: psutil in /home/joy/.local/lib/python3.8/site-packages (from ipykernel->nbclassic->jupyterlab>=3.0.0->leafmap) (5.9.1)
# Requirement already satisfied: debugpy>=1.0 in /home/joy/.local/lib/python3.8/site-packages (from ipykernel->nbclassic->jupyterlab>=3.0.0->leafmap) (1.6.2)
# Requirement already satisfied: fastjsonschema in /home/joy/.local/lib/python3.8/site-packages (from nbformat->nbclassic->jupyterlab>=3.0.0->leafmap) (2.16.1)
# Requirement already satisfied: ptyprocess; os_name != "nt" in /home/joy/.local/lib/python3.8/site-packages (from terminado>=0.8.3->nbclassic->jupyterlab>=3.0.0->leafmap) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /home/joy/.local/lib/python3.8/site-packages (from argon2-cffi->nbclassic->jupyterlab>=3.0.0->leafmap) (21.2.0)
# Requirement already satisfied: wcwidth in /home/joy/.local/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyterlab>=3.0.0->leafmap) (0.2.5)
# Requirement already satisfied: asttokens in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (2.0.5)
# Requirement already satisfied: pure-eval in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (0.2.2)
# Requirement already satisfied: executing in /home/joy/.local/lib/python3.8/site-packages (from stack-data->ipython->jupyterlab>=3.0.0->leafmap) (0.9.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/joy/.local/lib/python3.8/site-packages (from jedi>=0.16->ipython->jupyterlab>=3.0.0->leafmap) (0.8.3)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (21.4.0)
# Requirement already satisfied: importlib-resources>=1.4.0; python_version < "3.9" in /home/joy/.local/lib/python3.8/site-packages (from jsonschema>=3.0.1->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (5.7.1)
# Requirement already satisfied: zipp>=0.5 in /home/joy/.local/lib/python3.8/site-packages (from importlib-metadata>=3.6; python_version < "3.10"->jupyterlab-server~=2.10->jupyterlab>=3.0.0->leafmap) (3.8.0)
# Requirement already satisfied: sniffio>=1.1 in /home/joy/.local/lib/python3.8/site-packages (from anyio<4,>=3.1.0->jupyter-server~=1.16->jupyterlab>=3.0.0->leafmap) (1.2.0)
# Requirement already satisfied: webencodings in /home/joy/.local/lib/python3.8/site-packages (from bleach->nbconvert>=5->nbclassic->jupyterlab>=3.0.0->leafmap) (0.5.1)
# Requirement already satisfied: cffi>=1.0.1 in /home/joy/.local/lib/python3.8/site-packages (from argon2-cffi-bindings->argon2-cffi->nbclassic->jupyterlab>=3.0.0->leafmap) (1.14.0)
# Requirement already satisfied: pycparser in /home/joy/.local/lib/python3.8/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->nbclassic->jupyterlab>=3.0.0->leafmap) (2.19)
# Installing collected packages: ipysheet, pystac, pystac-client, leafmap
# Successfully installed ipysheet-0.5.0 leafmap-0.10.3 pystac-1.6.1 pystac-client-0.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import ee
import folium
import geemap.foliumap as geemap

# %% [markdown]
# The split-panel map requires two layers: `left_layer` and `right_layer`. The layer instance can be a string representing a basemap, or an HTTP URL to a Cloud Optimized GeoTIFF (COG), or a folium TileLayer instance.
#
# **Using basemaps**

# %% [markdown]
# Show available basemaps.

# %%
m = geemap.Map(height=500)
m.split_map(left_layer='ESA WorldCover 2020', right_layer='HYBRID')
legend_dict = {
    'Open Water': '466b9f',
    'Perennial Ice/Snow': 'd1def8',
    'Developed, Open Space': 'dec5c5',
    'Developed, Low Intensity': 'd99282',
    'Developed, Medium Intensity': 'eb0000',
    'Developed High Intensity': 'ab0000',
    'Barren Land (Rock/Sand/Clay)': 'b3ac9f',
    'Deciduous Forest': '68ab5f',
    'Evergreen Forest': '1c5f2c',
    'Mixed Forest': 'b5c58f',
    'Dwarf Scrub': 'af963c',
    'Shrub/Scrub': 'ccb879',
    'Grassland/Herbaceous': 'dfdfc2',
    'Sedge/Herbaceous': 'd1d182',
    'Lichens': 'a3cc51',
    'Moss': '82ba9e',
    'Pasture/Hay': 'dcd939',
    'Cultivated Crops': 'ab6c28',
    'Woody Wetlands': 'b8d9eb',
    'Emergent Herbaceous Wetlands': '6c9fb8',
}
# m.add_legend(legend_dict=legend_dict)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90f386fcb9c70cf7500c655457cff0db {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://raw.githack.com/digidem/leaflet-side-by-side/gh-pages/leaflet-side-by-side.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90f386fcb9c70cf7500c655457cff0db&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_90f386fcb9c70cf7500c655457cff0db = L.map(
#                 &quot;map_90f386fcb9c70cf7500c655457cff0db&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e310b52b4d2d44396fc1e8882a906691 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90f386fcb9c70cf7500c655457cff0db);
#
#
#             var tile_layer_800c863e4b4668fe4301fd58c1c226fa = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90f386fcb9c70cf7500c655457cff0db);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_90f386fcb9c70cf7500c655457cff0db);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_90f386fcb9c70cf7500c655457cff0db
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_8dd98471af638609046b646d8f3eeeb0 = new L.Control.Draw(
#                 options
#             ).addTo( map_90f386fcb9c70cf7500c655457cff0db );
#             map_90f386fcb9c70cf7500c655457cff0db.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_90f386fcb9c70cf7500c655457cff0db.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_90f386fcb9c70cf7500c655457cff0db.setView(e.geocode.center, 11);
#             }).addTo(map_90f386fcb9c70cf7500c655457cff0db);
#
#
#
#             map_90f386fcb9c70cf7500c655457cff0db.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_f6f2058cb7a09e9f3f393c00b9a662fb = L.tileLayer.wms(
#                 &quot;https://services.terrascope.be/wms/v2&quot;,
#                 {&quot;attribution&quot;: &quot;ESA&quot;, &quot;format&quot;: &quot;image/png&quot;, &quot;layers&quot;: &quot;WORLDCOVER_2020_MAP&quot;, &quot;styles&quot;: &quot;&quot;, &quot;transparent&quot;: true, &quot;version&quot;: &quot;1.1.1&quot;}
#             ).addTo(map_90f386fcb9c70cf7500c655457cff0db);
#
#
#             var tile_layer_bce58ef94233255e9a

# %%
m.save('lulc.html')

# %%
geemap.basemaps.keys()
# Out:
# dict_keys(['OpenStreetMap', 'ROADMAP', 'SATELLITE', 'TERRAIN', 'HYBRID', 'FWS NWI Wetlands', 'FWS NWI Wetlands Raster', 'NLCD 2019 CONUS Land Cover', 'NLCD 2016 CONUS Land Cover', 'NLCD 2013 CONUS Land Cover', 'NLCD 2011 CONUS Land Cover', 'NLCD 2008 CONUS Land Cover', 'NLCD 2006 CONUS Land Cover', 'NLCD 2004 CONUS Land Cover', 'NLCD 2001 CONUS Land Cover', 'USGS NAIP Imagery', 'USGS NAIP Imagery False Color', 'USGS NAIP Imagery NDVI', 'USGS Hydrography', 'USGS 3DEP Elevation', 'ESA WorldCover 2020', 'ESA WorldCover 2020 S2 FCC', 'ESA WorldCover 2020 S2 TCC', 'BasemapAT.basemap', 'BasemapAT.grau', 'BasemapAT.highdpi', 'BasemapAT.orthofoto', 'BasemapAT.overlay', 'BasemapAT.surface', 'BasemapAT.terrain', 'CartoDB.DarkMatter', 'CartoDB.DarkMatterNoLabels', 'CartoDB.DarkMatterOnlyLabels', 'CartoDB.Positron', 'CartoDB.PositronNoLabels', 'CartoDB.PositronOnlyLabels', 'CartoDB.Voyager', 'CartoDB.VoyagerLabelsUnder', 'CartoDB.VoyagerNoLabels', 'CartoDB.VoyagerOnlyLabels', 'CyclOSM', 'Esri.AntarcticBasemap', 'Esri.AntarcticImagery', 'Esri.ArcticImagery', 'Esri.ArcticOceanBase', 'Esri.ArcticOceanReference', 'Esri.DeLorme', 'Esri.NatGeoWorldMap', 'Esri.OceanBasemap', 'Esri.WorldGrayCanvas', 'Esri.WorldImagery', 'Esri.WorldPhysical', 'Esri.WorldShadedRelief', 'Esri.WorldStreetMap', 'Esri.WorldTerrain', 'Esri.WorldTopoMap', 'FreeMapSK', 'Gaode.Normal', 'Gaode.Satellite', 'GeoportailFrance.orthos', 'GeoportailFrance.parcels', 'GeoportailFrance.plan', 'HikeBike.HikeBike', 'HikeBike.HillShading', 'JusticeMap.americanIndian', 'JusticeMap.asian', 'JusticeMap.black', 'JusticeMap.hispanic', 'JusticeMap.income', 'JusticeMap.multi', 'JusticeMap.nonWhite', 'JusticeMap.plurality', 'JusticeMap.white', 'MtbMap', 'NASAGIBS.ASTER_GDEM_Greyscale_Shaded_Relief', 'NASAGIBS.BlueMarble', 'NASAGIBS.BlueMarble3031', 'NASAGIBS.BlueMarble3413', 'NASAGIBS.ModisAquaBands721CR', 'NASAGIBS.ModisAquaTrueColorCR', 'NASAGIBS.ModisTerraAOD', 'NASAGIBS.ModisTerraBands367CR', 'NASAGIBS.ModisTerraBands721CR', 'NASAGIBS.ModisTerraChlorophyll', 'NASAGIBS.ModisTerraLSTDay', 'NASAGIBS.ModisTerraSnowCover', 'NASAGIBS.ModisTerraTrueColorCR', 'NASAGIBS.ViirsEarthAtNight2012', 'NASAGIBS.ViirsTrueColorCR', 'NLS', 'OPNVKarte', 'OneMapSG.Default', 'OneMapSG.Grey', 'OneMapSG.LandLot', 'OneMapSG.Night', 'OneMapSG.Original', 'OpenAIP', 'OpenFireMap', 'OpenRailwayMap', 'OpenSeaMap', 'OpenSnowMap.pistes', 'OpenStreetMap.BZH', 'OpenStreetMap.BlackAndWhite', 'OpenStreetMap.CH', 'OpenStreetMap.DE', 'OpenStreetMap.France', 'OpenStreetMap.HOT', 'OpenStreetMap.Mapnik', 'OpenTopoMap', 'SafeCast', 'Stadia.AlidadeSmooth', 'Stadia.AlidadeSmoothDark', 'Stadia.OSMBright', 'Stadia.Outdoors', 'Stamen.Terrain', 'Stamen.TerrainBackground', 'Stamen.TerrainLabels', 'Stamen.Toner', 'Stamen.TonerBackground', 'Stamen.TonerHybrid', 'Stamen.TonerLabels', 'Stamen.TonerLines', 'Stamen.TonerLite', 'Stamen.TopOSMFeatures', 'Stamen.TopOSMRelief', 'Stamen.Watercolor', 'Strava.All', 'Strava.Ride', 'Strava.Run', 'Strava.Water', 'Strava.Winter', 'SwissFederalGeoportal.JourneyThroughTime', 'SwissFederalGeoportal.NationalMapColor', 'SwissFederalGeoportal.NationalMapGrey', 'SwissFederalGeoportal.SWISSIMAGE', 'USGS.USImagery', 'USGS.USImageryTopo', 'USGS.USTopo', 'WaymarkedTrails.cycling', 'WaymarkedTrails.hiking', 'WaymarkedTrails.mtb', 'WaymarkedTrails.riding', 'WaymarkedTrails.skating', 'WaymarkedTrails.slopes', 'nlmaps.grijs', 'nlmaps.luchtfoto', 'nlmaps.pastel', 'nlmaps.standaard', 'nlmaps.water'])

# %% [markdown]
# **Using COG**

# %%
m = geemap.Map(height=600, center=[39.4948, -108.5492], zoom=12)
url = 'https://opendata.digitalglobe.com/events/california-fire-2020/pre-event/2018-02-16/pine-gulch-fire20/1030010076004E00.tif'
url2 = 'https://opendata.digitalglobe.com/events/california-fire-2020/post-event/2020-08-14/pine-gulch-fire20/10300100AAC8DD00.tif'
m.split_map(url, url2)
m
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b025a3159a458724bbd308f1003488d1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.fullscreen/1.4.2/Control.FullScreen.min.css&quot;/&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.draw/1.0.2/leaflet.draw.css&quot;/&gt;
#     &lt;script src=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://unpkg.com/leaflet-control-geocoder/dist/Control.Geocoder.css&quot;/&gt;
#     &lt;script src=&quot;https://raw.githack.com/digidem/leaflet-side-by-side/gh-pages/leaflet-side-by-side.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b025a3159a458724bbd308f1003488d1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b025a3159a458724bbd308f1003488d1 = L.map(
#                 &quot;map_b025a3159a458724bbd308f1003488d1&quot;,
#                 {
#                     center: [39.4948, -108.5492],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                     eeInitialize: true,
#                     addGoogleMap: true,
#                     pluginLatlngpopup: false,
#                     pluginFullscreen: true,
#                     pluginDraw: true,
#                     DrawExport: false,
#                     pluginMinimap: false,
#                     pluginLayercontrol: false,
#                     locateControl: false,
#                     searchControl: true,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aba24162c857b853725f9719710b2b83 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 24, &quot;maxZoom&quot;: 24, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b025a3159a458724bbd308f1003488d1);
#
#
#             var tile_layer_846b11855d4a694d9cc1007935e5dc05 = L.tileLayer(
#                 &quot;https://mt1.google.com/vt/lyrs=m\u0026x={x}\u0026y={y}\u0026z={z}&quot;,
#                 {&quot;attribution&quot;: &quot;Google&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 22, &quot;maxZoom&quot;: 22, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b025a3159a458724bbd308f1003488d1);
#
#
#             L.control.fullscreen(
#                 {&quot;forceSeparateButton&quot;: false, &quot;position&quot;: &quot;topleft&quot;, &quot;title&quot;: &quot;Full Screen&quot;, &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;}
#             ).addTo(map_b025a3159a458724bbd308f1003488d1);
#
#
#             var options = {
#               position: &quot;topleft&quot;,
#               draw: {},
#               edit: {},
#             }
#             // FeatureGroup is to store editable layers.
#             var drawnItems = new L.featureGroup().addTo(
#                 map_b025a3159a458724bbd308f1003488d1
#             );
#             options.edit.featureGroup = drawnItems;
#             var draw_control_c752294b8010b313ce4e9d8fdd68362b = new L.Control.Draw(
#                 options
#             ).addTo( map_b025a3159a458724bbd308f1003488d1 );
#             map_b025a3159a458724bbd308f1003488d1.on(L.Draw.Event.CREATED, function(e) {
#                 var layer = e.layer,
#                     type = e.layerType;
#                 var coords = JSON.stringify(layer.toGeoJSON());
#                 layer.on(&#x27;click&#x27;, function() {
#                     alert(coords);
#                     console.log(coords);
#                 });
#                 drawnItems.addLayer(layer);
#              });
#             map_b025a3159a458724bbd308f1003488d1.on(&#x27;draw:created&#x27;, function(e) {
#                 drawnItems.addLayer(e.layer);
#             });
#
#
#
#             L.Control.geocoder(
#                 {&quot;collapsed&quot;: true, &quot;defaultMarkGeocode&quot;: true, &quot;position&quot;: &quot;topleft&quot;}
#             ).on(&#x27;markgeocode&#x27;, function(e) {
#                 map_b025a3159a458724bbd308f1003488d1.setView(e.geocode.center, 11);
#             }).addTo(map_b025a3159a458724bbd308f1003488d1);
#
#
#
#             map_b025a3159a458724bbd308f1003488d1.fitBounds(
#                 [[39.4948, -108.5492], [39.4948, -108.5492]],
#                 {&quot;maxZoom&quot;: 12}
#             );
#
#
#             var tile_layer_9d03a0484750e42d09dfc15d8650d10c = L.tileLayer(
#                 &quot;https://titiler.xyz/cog/tiles/WebMercatorQuad/{z}/{x}/{y}@1x?url=https%3A%2F%2Fopendata.digitalglobe.com%2Fevents%2Fcalifornia-fire-2020%2Fpre-event%2F2018-02-16%2Fpine-gulch-fire20%2F1030010076004E00.tif\u0026bidx=1\u0026bidx=2\u0026bidx=3\u0026rescale=1.0%2C251.0&quot;,
#                 {&quot;attribution&quot;: &quot; &quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18,

# %% [markdown]
# **Using folium TileLayer**

# %%
m = geemap.Map(center=[40, -100], zoom=4)

url1 = 'https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2001_Land_Cover_L48/wms?'
url2 = 'https://www.mrlc.gov/geoserver/mrlc_display/NLCD_2019_Land_Cover_L48/wms?'

left_layer = folium.WmsTileLayer(
    url=url1,
    layers='NLCD_2001_Land_Cover_L48',
    name='NLCD 2001',
    attr='MRLC',
    fmt="image/png",
    transparent=True,
)
right_layer = folium.WmsTileLayer(
    url=url2,
    layers='NLCD_2019_Land_Cover_L48',
    name='NLCD 2019',
    attr='MRLC',
    fmt="image/png",
    transparent=True,
)

m.split_map(left_layer, right_layer)
m

# %% [markdown]
# **Using Earth Engine layers**

# %%
m = geemap.Map(center=[39.3322, -106.7349], zoom=10)

# %%
srtm = ee.Image("USGS/SRTMGL1_003")
hillshade = ee.Terrain.hillshade(srtm)

# %%
vis = {
    'min': 0,
    'max': 5000,
    'palette': ["006633", "E5FFCC", "662A00", "D8D8D8", "F5F5F5"],
}

# %%
left_layer = geemap.ee_tile_layer(hillshade, name='Hillshade')
right_layer = geemap.ee_tile_layer(srtm, vis, name='DEM')

# %%
m.split_map(left_layer, right_layer)
m
